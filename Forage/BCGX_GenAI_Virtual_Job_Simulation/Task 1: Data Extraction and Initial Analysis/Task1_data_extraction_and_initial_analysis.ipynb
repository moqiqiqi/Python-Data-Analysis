# %% [markdown]
# # BCGX GenAI virtual Job Simulation

# %% [markdown]
# ### Compile the extracted data from the SEC\'s EDGAR database into an Excel spreadsheet

# %%
file_path = '10-k_data.xlsx'

# %% [markdown]
# ### Load the data from the Excel spreadsheet

# %%
import pandas as pd

# %%
df = pd.read_excel(file_path)

# %%
df
# Out:
#      Company  Year  Total Revenue  Net Income  Total Assets  \
# 0  Microsoft  2023         211915       72361        411976
# 1  Microsoft  2022         198270       72738        364840
# 2  Microsoft  2021         168088       61271        333779
# 3      Tesla  2023          96773       14974        106618
# 4      Tesla  2022          81462       12556         82338
# 5      Tesla  2021          53821        5519         62131
# 6      Apple  2023         383285       96995        352583
# 7      Apple  2022         394328       99803        352755
# 8      Apple  2021         365817       94680        351002
#
#    Total Liabilities  Cash Flow from Operating Activities
# 0             205753                                87582
# 1             198298                                89035
# 2             191791                                76740
# 3              43009                                13256
# 4              36440                                14724
# 5              30548                                11497
# 6             290437                               110543
# 7             302083                               122151
# 8             287912                               104038

# %% [markdown]
# ### Calculate year-over-year growth rates for each financial metric

# %%
df = df.sort_values(by=['Company', 'Year'])

# %%
df
# Out:
#      Company  Year  Total Revenue  Net Income  Total Assets  \
# 8      Apple  2021         365817       94680        351002
# 7      Apple  2022         394328       99803        352755
# 6      Apple  2023         383285       96995        352583
# 2  Microsoft  2021         168088       61271        333779
# 1  Microsoft  2022         198270       72738        364840
# 0  Microsoft  2023         211915       72361        411976
# 5      Tesla  2021          53821        5519         62131
# 4      Tesla  2022          81462       12556         82338
# 3      Tesla  2023          96773       14974        106618
#
#    Total Liabilities  Cash Flow from Operating Activities
# 8             287912                               104038
# 7             302083                               122151
# 6             290437                               110543
# 2             191791                                76740
# 1             198298                                89035
# 0             205753                                87582
# 5              30548                                11497
# 4              36440                                14724
# 3              43009                                13256

# %%
df['Revenue Growth (%)'] = df.groupby('Company')['Total Revenue'].pct_change() * 100
df['Net Income Growth (%)'] = df.groupby('Company')['Net Income'].pct_change() * 100
df['Total Assets Growth (%)'] = df.groupby('Company')['Total Assets'].pct_change() * 100
df['Total Liabilities Growth (%)'] = df.groupby('Company')['Total Liabilities'].pct_change() * 100
df['Cash Flow from Operating Activities Growth (%)'] = df.groupby('Company')['Cash Flow from Operating Activities'].pct_change() * 100

# %%
df
# Out:
#      Company  Year  Total Revenue  Net Income  Total Assets  \
# 8      Apple  2021         365817       94680        351002
# 7      Apple  2022         394328       99803        352755
# 6      Apple  2023         383285       96995        352583
# 2  Microsoft  2021         168088       61271        333779
# 1  Microsoft  2022         198270       72738        364840
# 0  Microsoft  2023         211915       72361        411976
# 5      Tesla  2021          53821        5519         62131
# 4      Tesla  2022          81462       12556         82338
# 3      Tesla  2023          96773       14974        106618
#
#    Total Liabilities  Cash Flow from Operating Activities  Revenue Growth (%)  \
# 8             287912                               104038                 NaN
# 7             302083                               122151            7.793788
# 6             290437                               110543           -2.800461
# 2             191791                                76740                 NaN
# 1             198298                                89035           17.956071
# 0             205753                                87582            6.882030
# 5              30548                                11497                 NaN
# 4              36440                                14724           51.357277
# 3              43009                                13256           18.795267
#
#    Net Income Growth (%)  Total Assets Growth (%)  \
# 8                    NaN                      NaN
# 7               5.410858                 0.499427
# 6              -2.813543                -0.048759
# 2                    NaN                      NaN
# 1              18.715216                 9.305858
# 0              -0.518299                12.919636
# 5                    NaN                      NaN
# 4             127.504983                32.523217
# 3              19.257725                29.488207
#
#    Total Liabilities Growth (%)  \
# 8                           NaN
# 7                      4.921990
# 6                     -3.855232
# 2                           NaN
# 1                      3.392756
# 0                      3.759493
# 5                           NaN
# 4                     19.287678
# 3                     18.026894
#
#    Cash Flow from Operating Activities Growth (%)
# 8                                             NaN
# 7                                       17.409985
# 6                                       -9.502992
# 2                                             NaN
# 1                                       16.021631
# 0                                       -1.631942
# 5                                             NaN
# 4                                       28.068192
# 3                                       -9.970117

# %%
(394328-365817)/365817*100
# Out:
# 7.7937876041846055

# %% [markdown]
# ### Fill NA values that from pct_change calculations with 0 or an appropriate value

# %%
df.fillna(0, inplace=True)

# %% [markdown]
# #### Display the dataframe to verify the calculations

# %%
df
# Out:
#      Company  Year  Total Revenue  Net Income  Total Assets  \
# 8      Apple  2021         365817       94680        351002
# 7      Apple  2022         394328       99803        352755
# 6      Apple  2023         383285       96995        352583
# 2  Microsoft  2021         168088       61271        333779
# 1  Microsoft  2022         198270       72738        364840
# 0  Microsoft  2023         211915       72361        411976
# 5      Tesla  2021          53821        5519         62131
# 4      Tesla  2022          81462       12556         82338
# 3      Tesla  2023          96773       14974        106618
#
#    Total Liabilities  Cash Flow from Operating Activities  Revenue Growth (%)  \
# 8             287912                               104038            0.000000
# 7             302083                               122151            7.793788
# 6             290437                               110543           -2.800461
# 2             191791                                76740            0.000000
# 1             198298                                89035           17.956071
# 0             205753                                87582            6.882030
# 5              30548                                11497            0.000000
# 4              36440                                14724           51.357277
# 3              43009                                13256           18.795267
#
#    Net Income Growth (%)  Total Assets Growth (%)  \
# 8               0.000000                 0.000000
# 7               5.410858                 0.499427
# 6              -2.813543                -0.048759
# 2               0.000000                 0.000000
# 1              18.715216                 9.305858
# 0              -0.518299                12.919636
# 5               0.000000                 0.000000
# 4             127.504983                32.523217
# 3              19.257725                29.488207
#
#    Total Liabilities Growth (%)  \
# 8                      0.000000
# 7                      4.921990
# 6                     -3.855232
# 2                      0.000000
# 1                      3.392756
# 0                      3.759493
# 5                      0.000000
# 4                     19.287678
# 3                     18.026894
#
#    Cash Flow from Operating Activities Growth (%)
# 8                                        0.000000
# 7                                       17.409985
# 6                                       -9.502992
# 2                                        0.000000
# 1                                       16.021631
# 0                                       -1.631942
# 5                                        0.000000
# 4                                       28.068192
# 3                                       -9.970117

# %%
summary = df.groupby('Company').agg({
    'Revenue Growth (%)': 'mean',
    'Net Income Growth (%)': 'mean',
    'Total Assets Growth (%)': 'mean',
    'Total Liabilities Growth (%)': 'mean',
    'Cash Flow from Operating Activities Growth (%)': 'mean'
})
#.reset_index()

# %%
print("Year-over-Year Average Growth Rates (%):")
summary
# Out:
# Year-over-Year Average Growth Rates (%):
#            Revenue Growth (%)  Net Income Growth (%)  Total Assets Growth (%)  \
# Company
# Apple                1.664442               0.865772                 0.150223
# Microsoft            8.279367               6.065639                 7.408498
# Tesla               23.384181              48.920903                20.670475
#
#            Total Liabilities Growth (%)  \
# Company
# Apple                          0.355586
# Microsoft                      2.384083
# Tesla                         12.438191
#
#            Cash Flow from Operating Activities Growth (%)
# Company
# Apple                                            2.635664
# Microsoft                                        4.796563
# Tesla                                            6.032692

# %%
df.to_csv('cleaned_financial_data.csv')
summary.to_csv('summary.csv')
